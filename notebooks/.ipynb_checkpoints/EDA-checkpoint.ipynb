# %%
import pandas as pd
import duckdb as db
import seaborn as sns
import plotly
import matplotlib.pyplot as plt
import numpy as np
import re
from nltk.corpus import stopwords
from collections import Counter

# %%
fake_news = pd.read_csv(r"D:\IT\Python\fake-news-detection\data\Fake.csv\Fake.csv")
true_news = pd.read_csv(r"D:\IT\Python\fake-news-detection\data\True.csv\True.csv")

# %%
def clean_df(df):
    df = df.copy()
    df = df.drop_duplicates(subset=["text", 'title'])
    mask = df['date'].str.contains(r"^\d{1,2}-\w+-\d{2}$", regex=True)
    df.loc[mask, 'date'] = pd.to_datetime(df.loc[mask, 'date'], format='%d-%b-%y').dt.strftime('%B %d, %Y')
    mask1 = df['date'].str.contains(r"^\w{3} \d{1,2}, \d{4}$", regex=True)
    df.loc[mask1, 'date'] = pd.to_datetime(df.loc[mask1, 'date'], format='%b %d, %Y').dt.strftime('%B %d, %Y')
    df['date_clean'] = pd.to_datetime(df['date'], format='mixed', errors='coerce')
    df = df.dropna(subset=['date_clean'])
    df = df.drop('date', axis=1)
    df = df.rename(columns = {'date_clean': 'date'})

    return df

# %%
def add_features(df):
    df = df.copy()
    df['word_count'] = df['text'].apply(lambda x: len(re.findall(r"\w+", x)), )
    df['character_count'] = df['text'].apply(lambda x: len(x))
    df['average_word_length'] = df['character_count']/df['word_count'].replace(0, np.nan)
    df["title_word_count"] = df['title'].apply(lambda x: len(re.findall(r'\w+', x)))
    df["title_character_count"] = df['title'].apply(lambda x: len(x))
    df["exclamation_count"] = df['text'].apply(lambda x: x.count('!'))
    df['uppercase_ratio'] = df['text'].apply(lambda x: (sum(1 for ch in x if ch.isupper()) / sum(1 for ch in x if ch.isalpha())) if any(ch.isalpha() for ch in x) else 0)
    df['url_count'] = df['text'].apply(lambda x: len(re.findall(r'https?|ftp', x)))

    return df

# %%
fake_news['is_fake'] = 1
true_news['is_fake'] = 0

# %%
fake_news.isna().sum()[fake_news.isna().sum()>0], true_news.isna().sum()[true_news.isna().sum()>0]
# Out:
# (Series([], dtype: int64), Series([], dtype: int64))

# %%
print(fake_news.duplicated().sum())
print(true_news.duplicated().sum())
# Out:
# 3
# 206

# %%
df = pd.concat([fake_news, true_news])

# %%
df.shape
# Out:
# (44898, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 44898 entries, 0 to 21416
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  str
#  1   text     44898 non-null  str
#  2   subject  44898 non-null  str
#  3   date     44898 non-null  str
#  4   is_fake  44898 non-null  int64
# dtypes: int64(1), str(4)
# memory usage: 112.6 MB

# %%
df['is_fake'].value_counts(normalize=True)
# Out:
# is_fake
# 1    0.522985
# 0    0.477015
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  is_fake
# 0  December 31, 2017        1
# 1  December 31, 2017        1
# 2  December 30, 2017        1
# 3  December 29, 2017        1
# 4  December 25, 2017        1

# %%
df.duplicated(subset=["text", 'title']).sum()
# Out:
# np.int64(5793)

# %%
len(df)
# Out:
# 44898

# %%
df = clean_df(df)
df = add_features(df)

# %%
df.nsmallest(3, 'word_count')['word_count']
df.groupby('is_fake')[['uppercase_ratio', 'url_count', 'exclamation_count', 'title_character_count', 'title_word_count', 'average_word_length', 'character_count', 'word_count']].mean()
# Out:
#          uppercase_ration  url_count  exclamation_count  \
# is_fake
# 0                 0.00000   0.000000           0.062131
# 1                 0.00237   0.203664           0.723606
#
#          title_character_count  title_word_count  average_word_length  \
# is_fake
# 0                    64.658631         10.508515             6.083763
# 1                    91.253938         15.071165             5.798371
#
#          character_count  word_count
# is_fake
# 0            2378.697646  393.037930
# 1            2487.223550  427.802145

# %%
sns.countplot(data=df, x='is_fake')
plt.xticks([0, 1], ['Real', 'Fake'])
plt.tight_layout()

# %%
sns.countplot(data=df, x='subject', hue='is_fake', dodge='multiple')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# average_word_length    447
# dtype: int64

# %%
a = df.groupby([df['date'].dt.year, 'is_fake'], as_index=False).size()
sns.barplot(data=a, x='date', y='size', hue='is_fake')
# Out:
# <Axes: xlabel='date', ylabel='size'>

# %%
sns.histplot(data=df, x='word_count', bins=35, hue='is_fake')
# Out:
# <Axes: xlabel='word_count', ylabel='Count'>

# %%
sns.histplot(data=df, x='character_count', bins=20, hue='is_fake')
# Out:
# <Axes: xlabel='character_count', ylabel='Count'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x="is_fake", y="word_count")
# Out:
# <Axes: xlabel='is_fake', ylabel='word_count'>

# %%
stopword = set(stopwords.words('english'))

# %%
fake_news_words = [word.lower() for text in df.loc[df['is_fake'] == 1, 'text'] for word in re.findall(r"[A-Za-z]+", text.lower()) if word.isalpha() and word not in stopword]
fake_news_words_count = Counter(fake_news_words)
fake_news_words_count = Counter(fake_news_words)
fake_news_words_count.most_common(20)
# Out:
# [('trump', 68657),
#  ('said', 24814),
#  ('people', 21217),
#  ('president', 20864),
#  ('one', 18911),
#  ('would', 18268),
#  ('donald', 15398),
#  ('like', 14388),
#  ('clinton', 13556),
#  ('obama', 13416),
#  ('also', 11416),
#  ('even', 11367),
#  ('via', 11093),
#  ('time', 10731),
#  ('new', 10415),
#  ('white', 10314),
#  ('news', 10263),
#  ('hillary', 10001),
#  ('us', 9877),
#  ('twitter', 9516)]

# %%
true_news_words = [word.lower() for text in df.loc[df['is_fake'] == 0, 'text'] for word in re.findall(r"[A-Za-z]+", text.lower()) if word.isalpha() and word not in stopword]
true_news_words_count = Counter(true_news_words)
true_news_words_count = Counter(true_news_words)
true_news_words_count.most_common(20)
# Out:
# [('said', 97831),
#  ('trump', 54082),
#  ('u', 44029),
#  ('would', 31240),
#  ('reuters', 28661),
#  ('president', 27863),
#  ('state', 20800),
#  ('government', 18550),
#  ('new', 16740),
#  ('house', 16485),
#  ('states', 16417),
#  ('republican', 16140),
#  ('also', 15750),
#  ('united', 15365),
#  ('people', 15081),
#  ('year', 14595),
#  ('told', 14068),
#  ('could', 13534),
#  ('one', 13247),
#  ('washington', 12886)]

# %%
conn = db.connect()

# %%
avg_word_count_per_year = db.sql("""
select year(date) as year, avg(word_count) as avg_word_count from df group by year order by avg_word_count desc""").df()

# %%
mix = db.execute("""
select subject, avg(title_word_count) as avg_title_word_count, round(avg(exclamation_count), 2) as avg_exclamation_count from df group by subject order by avg_title_word_count desc
""").df()

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  is_fake  \
# 0  Donald Trump just couldn t wish all Americans ...    News        1
# 1  House Intelligence Committee Chairman Devin Nu...    News        1
# 2  On Friday, it was revealed that former Milwauk...    News        1
# 3  On Christmas day, Donald Trump announced that ...    News        1
# 4  Pope Francis used his annual Christmas Day mes...    News        1
#
#         date  word_count  character_count  average_word_length  \
# 0 2017-12-31         504             2893             5.740079
# 1 2017-12-31         316             1898             6.006329
# ...

# %%
numbers_of_news_by_month = db.sql("""select month(date) as month, count(*) as number_of_occurances from df group by month(date) order by number_of_occurances desc
""").df()

# %%
avg_word_count_by_subject = db.sql("""select subject, avg(word_count) as avg_word_count from df group by subject order by avg_word_count desc
""").df()

# %%
sns.violinplot(data=df, x='is_fake', y='character_count')
# Out:
# <Axes: xlabel='is_fake', ylabel='character_count'>
